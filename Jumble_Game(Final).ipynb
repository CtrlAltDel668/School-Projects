# %%
import random
class Jumble_Game():
    
    def __init__(self,player):
        self.player = player
    
    def play(self):
        Hp = 3
        Score = 0
        temp_cat= []
        print('********************************************************')
        print('Legend:')
        print('    Category 1(ANIMALS) press 1')
        print('    Category 2(COUNTRIES) press 2')
        print('    Category 3(DINOSAURS) press 3')
        print('********************************************************')
        y = int(input('Enter a number(1-3) : '))
        if y == 1:
            temp_cat.append('cat')
            temp_cat.append('ram')
            temp_cat.append('skunk')
            temp_cat.append('peacock')
            temp_cat.append('wildebeest')
        if y == 2:
            temp_cat.append('cuba')
            temp_cat.append('chad')
            temp_cat.append('ukraine')
            temp_cat.append('bahrain')
            temp_cat.append('afghanistan')
        if y == 3:
            temp_cat.append('aardonyx')
            temp_cat.append('triceratops')
            temp_cat.append('tyrannosaurus')
            temp_cat.append('apatosaurus')
            temp_cat.append('brachiosaurus')
        
        while True :
            
            while True :
                list1 = temp_cat
                x = list1[0]
                char_word = list(x)
                random.shuffle(char_word)
                name1 = ','.join(char_word)
                if y == 1 :
                    print(char_word)
                    input_word = input('Enter a word : ')
                        
                    if input_word == x :
                        print('Correct!')
                        Score = Score + 1
                        list1.remove(x)
                    else :
                        hint = random.randint(1,2)
                ##########################CAT##################################
                        if hint == 1 and x == 'cat' :
                            print('H!NT : IT IS A MAMMAL')
                        if hint == 2 and x == 'cat' :
                            print('H!NT : IT IS A DOMESTICATED ANIMAL')
                ###########################RAM#################################
                        if hint == 1 and x == 'ram' :
                            print('H!NT : IT IS A BIGHORN SHEEP')
                        if hint == 2 and x == 'ram' :
                            print('H!NT : IT IS SIMILAR TO GOAT')
                
                ############################SKUNK################################
                        if hint == 1 and x == 'skunk' :
                            print('H!NT : IT IS RELATED TO POLECATS')
                        if hint == 2 and x == 'skunk' :
                            print('H!NT : IT IS KNOWN FOR THEIR ABILITY TO SPRAY A LIQUID WITH A STRONG, UNPLEASANT SMELL')
                ############################PEACOCK################################
                        if hint == 1 and x == 'peacock' :
                            print('H!NT : IT IS A MALE PEAFOWL')
                        if hint == 2 and x == 'peacock' :
                            print('H!NT : IT IS A TYPE OF BIRD WITH A BEAUTIFUL TAIL')
                ############################WILDEBEEST################################
                        if hint == 1 and x == 'wildebeest' :
                            print('H!NT : IT IS CALLED GNU')
                        if hint == 2 and x == 'horse' :
                            print('H!NT : IT BELONGS TO THE FAMILY OF BOVIDAE')
                            
                if y == 2 :
                    print(char_word)
                    input_word = input('Enter a word : ')
                        
                    if input_word == x :
                        print('Correct!')
                        Score = Score + 1
                        list1.remove(x)
                    else :
                        
                        hint = random.randint(1,2)
                #############################CUBA###############################
                        if hint == 1 and x == 'cuba' :
                            print('H!NT : IT IS LOCATED IN THE NORTHERN CARIBBEAN')
                        if hint == 2 and x == 'cuba' :
                            print('H!NT : IT IS THE LARGEST ISLAND IN THE CARIBBEAN')
                #############################CHAD###############################
                        if hint == 1 and x == 'chad' :
                            print('H!NT : IT IS A LANDLOCKED COUNTRY IN NORTH-CENTRAL AFRICA')
                        if hint == 2 and x == 'chad' :
                            print('H!NT : THERE OFFICIAL LANGUAGES ARE ARABIC AND FRENCH')
                #############################UKRAINE###############################
                        if hint == 1 and x == 'ukraine' :
                            print('H!NT : IT IS A LARGE COUNTRY IN EASTERN EUROPE')
                        if hint == 2 and x == 'ukraine' :
                            print('H!NT : IT IS KNOWN FOR ITS ORTHODOX CHURCHES AND BLACK SEA COASTLINE')
                #############################BAHRAIN###############################
                        if hint == 1 and x == 'bahrain' :
                            print('H!NT : IT IS AN ISLAND COUNTRY IN THE PERSIAN GULF')
                        if hint == 2 and x == 'bahrain' :
                            print('H!NT : IT IS CONSIDERED AS THE 111TH SAFEST COUNTRY IN THE WORLD')
                #############################AFGHANISTAN###############################
                        if hint == 1 and x == 'afghanistan' :
                            print('H!NT : IT IS A LANDLOCKED COUNTRY IN SOUTH-CENTRAL ASIA')
                        if hint == 2 and x == 'afghanistan' :
                            print('H!NT : THE NAME OF THEIR CAPITAL IS KABUL')
                    
                if y == 3 :
                    print(char_word)
                    input_word = input('Enter a word : ')
                        
                    if input_word == x :
                        print('Correct!')
                        Score = Score + 1
                        list1.remove(x)
                    else :
                        hint = random.randint(1,2)
                #############################AARDONYX###############################
                        if hint == 1 and x == 'aardonyx' :
                            print('H!NT : IT IS A HERBIVORE DINOSAUR')
                        if hint == 2 and x == 'aardonyx' :
                            print('H!NT : IT IS CAPABLE OF BOTH BIPEDAL AND QUADRUPEDAL (MAKALAKAW)')
                #############################TRICERATOPS###############################
                        if hint == 1 and x == 'triceratops' :
                            print('H!NT : IT IS A HERBIVORE DINOSAUR')
                        if hint == 2 and x == 'triceratops' :
                            print('H!NT : IT HAS TWO HORNS, NOT THREE')
                #############################TYRANNOSAURUS###############################
                        if hint == 1 and x == 'tyrannosaurus' :
                            print('H!NT : IT IS OFTEN CALLED T-REX')
                        if hint == 2 and x == 'tyrannosaurus' :
                            print('H!NT : IT IS ONE OF THE LARGEST MEAT-EATING DINOSAUR')
                #############################APATOSAURUS###############################
                        if hint == 1 and x == 'apatosaurus' :
                            print('H!NT : IT IS ONE OF THE LARGEST DINOSAURS THAT EVER LIVED')
                        if hint == 2 and x == 'apatosaurus' :
                            print('H!NT : IT HAS A LONG AND WIDE NECK')
                #############################BRACHIOSAURUS###############################
                        if hint == 1 and x == 'brachiosaurus' :
                            print('H!NT : GIRAFFEE-LIKE DINOSAUR')
                        if hint == 2 and x == 'brachiosaurus' :
                            print('H!NT : IT IS A HERBIVORE DINOSAUR')
                    
                    
                if input_word != x :
                    break
                if (len(list1)) == 0 :
                    print('CONGRATULATIONS!! YOU CLEARED THE CATEGORY!!')
                    break
                
            if (len(list1)) == 0 :
                print('SCORE : ',Score)
                break 
            Hp = Hp - 1        
            if Hp == 0:
                print('GAMEOVER!!!')
                print('SCORE : ',Score)
                break

# %%
x = Jumble_Game('Kent')
x.play()
# Out:
# ********************************************************
# Legend:
#     Category 1(ANIMALS) press 1
#     Category 2(COUNTRIES) press 2
#     Category 3(DINOSAURS) press 3
# ********************************************************
# Enter a number(1-3) : 1
# ['t', 'c', 'a']
# Enter a word : qweqwe
# H!NT : IT IS A MAMMAL
# ['a', 't', 'c']
# Enter a word : rqwr
# H!NT : IT IS A DOMESTICATED ANIMAL
# ['a', 't', 'c']
# Enter a word : cat
# Correct!
# ['r', 'm', 'a']
# Enter a word : ram
# Correct!
# ['n', 's', 'k', 'k', 'u']
# Enter a word : skunk
# Correct!
# ['a', 'k', 'c', 'e', 'p', 'c', 'o']
# Enter a word : peacock
# Correct!
# ['l', 't', 'd', 'e', 'i', 's', 'e', 'b', 'w', 'e']
# Enter a word : wildebeest
# Correct!
# CONGRATULATIONS!! YOU CLEARED THE CATEGORY!!
# SCORE :  5
